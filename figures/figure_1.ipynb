# %% [markdown]
# # Figure 1

# %%
from src.comparison import plot_rmse_resolution

# %%
figure_name_prefix = 'Figure_1'
model_ref = 'miost'

image_format = 'png'
dpi = 600
resources_path = './resources'
target_path = './images'

# %%
model_name = 'NeurOST SSH'
model_file = 'neurostssh'

plot_rmse_resolution(
    f"a) Gain and loss of {model_name} compared to MIOST",
    model_file, model_ref,
    show_cbar=False, show_axis_legend=[False, False, False, False],
    suptitley=.78, figure_name_prefix=figure_name_prefix,
    resources_path=resources_path, target_path=target_path, dpi=dpi,
)

# %%
model_name = 'UNet'
model_file = 'unet'

plot_rmse_resolution(
    f"b) Gain and loss of {model_name} compared to MIOST",
    model_file, model_ref,
    show_cbar=False, show_axis_legend=[False, False, False, False],
    suptitley=.78, figure_name_prefix=figure_name_prefix,
    resources_path=resources_path, target_path=target_path, dpi=dpi,
)

# %%
model_name = '4DVarNet-UNet'
model_file = 'fdvarnet_unet'

plot_rmse_resolution(
    f"c) Gain and loss of {model_name} compared to MIOST",
    model_file, model_ref,
    show_cbar=True, show_axis_legend=[False, False, False, False],
    suptitley=.88, figure_name_prefix=figure_name_prefix,
    resources_path=resources_path, target_path=target_path, dpi=dpi,
)
